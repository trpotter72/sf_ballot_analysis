# %% [markdown]
# # SF Ballot Data
#
# ## Data Sources
#
# ### Department of Elections eData
#
# https://www.sfelections.org/tools/election_data/dataset.php?ATAB=d2022-11-08
#
# Generally, descriptive data on candidates, precincts, contests (all of labels)
#
# ### CVR (Cast Vote Record) Data
#
# https://sfelections.sfgov.org/november-8-2022-election-results-detailed-reports
#
# We have 22,193 json dumps which contain several ballots in each dump.  Important parts of each ballot:
#
# * `PrecinctPortionId` -  Join to `PrecinctPortionManifest.json` to get precinct description.  Join decription with neighborhood `breakdown.xlxs` from other data source above for zip codes & neighborhoods.
#
# * `BallotTypeId` - Join to `BallotTypeManifest.json` to get description.  (Not actually sure what this informs)
#
# * List of `cards`, each of which contains a list of:
#     * List of `contests`. Join to `ContestManifest.json` to interpret the issue voted on. Contents per contest:
#         * `CandidateManifest.json` for candidates
#         * `PartyManifest.json` for party
#         * `OutstackConditionManifest.json` describes for write-ins / undervotes / overvotes / ambiguous / blank-ballot
#         * List of candidates ranked, 1 being highest priority.  (Only 2 contests ask for >1 vote, "member BoE" & "member community college board"
#
# ## Framework
#
# 1) Pull in data, flesh out some descriptive language above, and have raw pandas dataframes below in a format more useful than JSON dumps
# 2) Create some flattened data sources
#     1) Single ballots.  Column for every contest.  Annotate with precint id, tabulator id, ballot-type id.  Segment out votes with 'problems'
#     2) ...
# 3) Join flattened data against all the manifests.  Join against neighborhoods
# 4) Analysis
#     1) Check against existing records to validate load
#     2) Contest D & E votes vs neighborhood analysis (There's turn-out percentages by neighborhood provided, but it's an excel sheet that looks meh to parse)

# %%
import pandas as pd
import numpy as np
import glob
import json
import tqdm.notebook as tqdm

# %%
# Web browser incantation to style so we can use the full screen space
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# info on the ~21 ballot items 
measures_df = pd.read_csv('./measures.txt',sep='\t',encoding='utf-16')
measures_df.head(5)
# Out:
#    iMeasureID sDesignation                                     szMeasureAbbr1  \
# 0         100            A  Retiree Supplemental Cost Of Living Adjustment...
# 1         101            B  Public Works Department And Commission, Sanita...
# 2         102            C                  Homelessness Oversight Commission
# 3         103            D           Affordable Housing - Initiative Petition
# 4         104            E          Affordable Housing - Board Of Supervisors
#
#    szMeasureAbbr2  iBallotPosition1  iBallotPosition2 dtDateReceived  \
# 0             NaN                 1                 2      8/12/2022
# 1             NaN                 1                 2      8/12/2022
# 2             NaN                 1                 2      8/12/2022
# 3             NaN                 1                 2      8/12/2022
# 4             NaN                 1                 2      8/12/2022
#
#    szReceivedBy  szRemarks  szFilerTitle  ...  sStyle  szLegalNoticePubDesc  \
# 0           NaN        NaN           NaN  ...     NaN                   NaN
# 1           NaN        NaN           NaN  ...     NaN                   NaN
# 2           NaN        NaN           NaN  ...     NaN                   NaN
# 3           NaN        NaN           NaN  ...     NaN                   NaN
# 4           NaN        NaN           NaN  ...     NaN                   NaN
#
#    szDeliveryMethodDesc                        szGroupHdg  \
# 0                   NaN  MEASURES SUBMITTED TO THE VOTERS
# 1                   NaN  MEASURES SUBMITTED TO THE VOTERS
# 2                   NaN  MEASURES SUBMITTED TO THE VOTERS
# 3                   NaN  MEASURES SUBMITTED TO THE VOTERS
# 4                   NaN  MEASURES SUBMITTED TO THE VOTERS
#
#                 szBallotHeading  szSubHeading  sDistrictID  szDistrictName  \
# 0  CITY AND COUNTY PROPOSITIONS           NaN           *0     County Wide
# 1  CITY AND COUNTY PROPOSITIONS           NaN           *0     County Wide
# 2  CITY AND COUNTY PROPOSITIONS           NaN           *0     County Wide
# 3  CITY AND COUNTY PROPOSITIONS           NaN           *0     County Wide
# 4  CITY AND COUNTY PROPOSITIONS           NaN           *0     County Wide
#
#                                   szElectionDesc  dtElectionDate
# 0  November 8 2022 Consolidated General Election       11/8/2022
# 1  November 8 2022 Consolidated General Election       11/8/2022
# 2  November 8 2022 Consolidated General Election       11/8/2022
# 3  November 8 2022 Consolidated General Election       11/8/2022
# 4  November 8 2022 Consolidated General Election       11/8/2022
#
# [5 rows x 50 columns]

# %%
# neighborhood and zip breakdowns
breakdown_df = pd.read_excel('./breakdown.xlsx')
breakdown_df.head(5)
# Out:
#       sZip  consolidation szVotingPrecinctName MailBallotPrecinct  iBalType  \
# 0  94127.0           1101             Pct 1101                 No         1
# 1  94132.0           1101             Pct 1101                 No         1
# 2  94132.0           1102             Pct 1102                 No         1
# 3  94132.0           1103          Pct 1103 MB                Yes         1
# 4  94132.0           1104             Pct 1104                 No         2
#
#    Assembly  BART  Congressional  Senatorial  Supervisorial  \
# 0        19     8             11          11             11
# 1        19     8             11          11             11
# 2        19     8             11          11             11
# 3        19     8             11          11             11
# 4        19     8             15          11             11
#
#                  Neighborhood
# 0  OCEANVIEW/MERCED/INGLESIDE
# 1  OCEANVIEW/MERCED/INGLESIDE
# 2  OCEANVIEW/MERCED/INGLESIDE
# 3  OCEANVIEW/MERCED/INGLESIDE
# 4  OCEANVIEW/MERCED/INGLESIDE

# %% [markdown]
# ## Start CRV Data Decoding

# %%
# All of the manifest files in the CRV data have the same JSON structure.
# Note that the BallotTypeContestManifest.json doesn't fit the schema, 
# looks like its a mapping of the contests on a given ballot type
def load_manifest(file_path):
    with open(file_path) as f:
        res=json.load(f)
    manifest_df = pd.DataFrame(res['List'])
    manifest_df.set_index('Id', inplace=True)
    return manifest_df

# %%
# What types of Contests are to be voted on given a ballot type?
ballot_type_contest_manifest_df = load_manifest('./CVR_Export/BallotTypeManifest.json')
ballot_type_contest_manifest_df.head(5)
# Out:
#              Description ExternalId
# Id
# 1   Ballot Type 23 - VBM
# 2   Ballot Type 27 - VBM
# 3   Ballot Type 26 - VBM
# 4    Ballot Type 1 - VBM
# 5   Ballot Type 19 - VBM

# %%
candidate_manifest_df = load_manifest('./CVR_Export/CandidateManifest.json')
candidate_manifest_df.head(5)
# Out:
#                    Description ExternalId  ContestId     Type  Disabled
# Id
# 1                  BRIAN DAHLE                     1  Regular         0
# 2                 GAVIN NEWSOM                     1  Regular         0
# 3   ANGELA E. UNDERWOOD JACOBS                     2  Regular         0
# 4             ELENI KOUNALAKIS                     2  Regular         0
# 5                 ROB BERNOSKY                     3  Regular         0

# %%
contest_manifest_df = load_manifest('./CVR_Export/ContestManifest.json')
contest_manifest_df
# Out:
#             Description ExternalId  DistrictId  VoteFor  NumOfRanks  Disabled
# Id
# 1              GOVERNOR       4000         101        1           0         0
# 2   LIEUTENANT GOVERNOR       4010         101        1           0         0
# 3    SECRETARY OF STATE       4020         101        1           0         0
# 4            CONTROLLER       4030         101        1           0         0
# 5             TREASURER       4040         101        1           0         0
# ..                  ...        ...         ...      ...         ...       ...
# 57            Measure J        109         116        1           0         0
# 59            Measure L        111         116        1           0         0
# 60            Measure M        112         116        1           0         0
# 61            Measure N        113         116        1           0         0
# 62            Measure O        114         116        1           0         0
#
# [66 rows x 6 columns]

# %%
outstack_condition_manifest_df = load_manifest('./CVR_Export/OutstackConditionManifest.json')
outstack_condition_manifest_df.head(5)
# Out:
#     Description
# Id
# 0     Ambiguous
# 1       Writein
# 2   BlankBallot
# 5      Overvote
# 4     Undervote

# %%
cvr_precinct_portion_manifest_df = load_manifest('./CVR_Export/PrecinctPortionManifest.json')
cvr_precinct_portion_manifest_df.head(5)
# Out:
#     Description ExternalId  PrecinctId
# Id
# 1      PCT 1101     1101-1           1
# 2      PCT 1102     1102-1           2
# 3   PCT 1103 MB     1103-1           3
# 4      PCT 1104     1104-2           4
# 5      PCT 1105     1105-2           5

# %%
# Tabulator ID to locations names
cvr_tabulator_df = load_manifest('./CVR_Export/TabulatorManifest.json')
cvr_tabulator_df.head(5)
# Out:
#            Description  VotingLocationNumber     VotingLocationName  \
# Id
# 1   ICC01 Election Day                     1  City Hall Vote Center
# 2   ICC01 Vote by Mail                     1  City Hall Vote Center
# 3   ICC02 Election Day                     1  City Hall Vote Center
# 4   ICC02 Vote by Mail                     1  City Hall Vote Center
# 5   ICC03 Election Day                     1  City Hall Vote Center
#
#    ExternalId              Type  ThresholdMin  ThresholdMax  \
# Id
# 1              ImagecastCentral             5            25
# 2              ImagecastCentral             5            25
# 3              ImagecastCentral             5            25
# 4              ImagecastCentral             5            25
# 5              ImagecastCentral             5            25
#
#     WriteThresholdMin  WriteThresholdMax
# Id
# 1                   5                 25
# 2                   5                 25
# 3                   5                 25
# 4                   5                 25
# 5                   5                 25

# %%
# What types of Contests are to be voted on given a ballot type?
with open('./CVR_Export/BallotTypeContestManifest.json') as f:
    res=json.load(f)
ballot_type_contest_manifest_df = pd.DataFrame(res['List'])
print(len(ballot_type_contest_manifest_df))
ballot_type_contest_manifest_df
# Out:
# 3748
#       BallotTypeId  ContestId
# 0                1          1
# 1                1          2
# 2                1          3
# 3                1          4
# 4                1          5
# ...            ...        ...
# 3743            80         68
# 3744            80         59
# 3745            80         60
# 3746            80         61
# 3747            80         62
#
# [3748 rows x 2 columns]

# %%
# These functions help unpack the per-ballot nested contest structure into something flat for our df
def marks_to_winner(marks):
    if not marks:
        return np.nan
    for mark in marks:
        if mark['Rank'] == 1:
            return mark['CandidateId']
#     raise RuntimeError(f"No 1st rank selected\n{marks}")
    return np.nan
    
def raw_ballot_to_flat(b):
    tabulator_id = b['TabulatorId']
    orig_ballot = b['Original']
    flat = {}
    
    # For each paper card scanned, mark the winner for the contests (each contest will be a column)
    for card in orig_ballot['Cards']:
        flat.update({f'contest_{contest["Id"]}': marks_to_winner(contest['Marks']) for contest in card['Contests']})
    
    flat.update({
        'precinct_portion_id': orig_ballot['PrecinctPortionId'],
        'ballot_type_id': orig_ballot['BallotTypeId'],
        'key_in_id': orig_ballot['Cards'][0]['KeyInId'],
        'tabulator_id': tabulator_id
    })
    return flat

# %%
with open('./CVR_Export/CvrExport_0.json') as f:
    res=json.load(f)
crv_export_df = pd.DataFrame(res['Sessions'])

# %%
crv_export_df.loc[0].Original['Cards']
# Out:
# [{'Id': 54860,
#   'KeyInId': 54860,
#   'PaperIndex': 0,
#   'Contests': [{'Id': 1,
#     'ManifestationId': 81779,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 2,
#       'ManifestationId': 252694,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 2,
#     'ManifestationId': 81780,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 4,
#       'ManifestationId': 252696,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 3,
#     'ManifestationId': 81781,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 6,
#       'ManifestationId': 252698,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 4,
#     'ManifestationId': 81782,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 8,
#       'ManifestationId': 252700,
#       'PartyId': 2,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 5,
#     'ManifestationId': 81783,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 9,
#       'ManifestationId': 252701,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 6,
#     'ManifestationId': 81784,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 11,
#       'ManifestationId': 252703,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 7,
#     'ManifestationId': 81785,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 14,
#       'ManifestationId': 252706,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 8,
#     'ManifestationId': 81786,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 16,
#       'ManifestationId': 252708,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 9,
#     'ManifestationId': 81787,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 17,
#       'ManifestationId': 252709,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 10,
#     'ManifestationId': 81788,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 19,
#       'ManifestationId': 252711,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 12,
#     'ManifestationId': 81789,
#     'Undervotes': 1,
#     'Overvotes': 0,
#     'OutstackConditionIds': [4, 6],
#     'Marks': []},
#    {'Id': 13,
#     'ManifestationId': 81790,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 26,
#       'ManifestationId': 252716,
#       'PartyId': 1,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 15,
#     'ManifestationId': 81791,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 29,
#       'ManifestationId': 252717,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 16,
#     'ManifestationId': 81792,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 35,
#       'ManifestationId': 252719,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 17,
#     'ManifestationId': 81793,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 33,
#       'ManifestationId': 252721,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 18,
#     'ManifestationId': 81794,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 31,
#       'ManifestationId': 252723,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]}],
#   'OutstackConditionIds': []},
#  {'Id': 54861,
#   'KeyInId': 54861,
#   'PaperIndex': 1,
#   'Contests': [{'Id': 19,
#     'ManifestationId': 120799,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 37,
#       'ManifestationId': 375378,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 20,
#     'ManifestationId': 120800,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 39,
#       'ManifestationId': 375380,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 21,
#     'ManifestationId': 120801,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 45,
#       'ManifestationId': 375382,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 22,
#     'ManifestationId': 120802,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 41,
#       'ManifestationId': 375384,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 23,
#     'ManifestationId': 120803,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 43,
#       'ManifestationId': 375386,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 24,
#     'ManifestationId': 120804,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 47,
#       'ManifestationId': 375388,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 25,
#     'ManifestationId': 120805,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 49,
#       'ManifestationId': 375390,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 26,
#     'ManifestationId': 120806,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 51,
#       'ManifestationId': 375392,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 27,
#     'ManifestationId': 120807,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 53,
#       'ManifestationId': 375394,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 28,
#     'ManifestationId': 120808,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 56,
#       'ManifestationId': 375397,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 29,
#     'ManifestationId': 120809,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 61,
#       'ManifestationId': 375403,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []},
#      {'CandidateId': 57,
#       'ManifestationId': 375399,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []},
#      {'CandidateId': 58,
#       'ManifestationId': 375400,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 30,
#     'ManifestationId': 120810,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 73,
#       'ManifestationId': 375416,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []},
#      {'CandidateId': 74,
#       'ManifestationId': 375417,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []},
#      {'CandidateId': 67,
#       'ManifestationId': 375410,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 31,
#     'ManifestationId': 120811,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 78,
#       'ManifestationId': 375423,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]}],
#   'OutstackConditionIds': []},
#  {'Id': 54862,
#   'KeyInId': 54862,
#   'PaperIndex': 2,
#   'Contests': [{'Id': 33,
#     'ManifestationId': 118962,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [14],
#     'Marks': [{'CandidateId': 82,
#       'ManifestationId': 369604,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 34,
#     'ManifestationId': 118963,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [14],
#     'Marks': [{'CandidateId': 87,
#       'ManifestationId': 369625,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 35,
#     'ManifestationId': 118964,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [14],
#     'Marks': [{'CandidateId': 90,
#       'ManifestationId': 369636,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]}],
#   'OutstackConditionIds': []},
#  {'Id': 54863,
#   'KeyInId': 54863,
#   'PaperIndex': 3,
#   'Contests': [{'Id': 41,
#     'ManifestationId': 80049,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 109,
#       'ManifestationId': 247016,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 42,
#     'ManifestationId': 80050,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 112,
#       'ManifestationId': 247019,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 43,
#     'ManifestationId': 80051,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 114,
#       'ManifestationId': 247021,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 44,
#     'ManifestationId': 80052,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 116,
#       'ManifestationId': 247023,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 45,
#     'ManifestationId': 80053,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 118,
#       'ManifestationId': 247025,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 46,
#     'ManifestationId': 80054,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 119,
#       'ManifestationId': 247026,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 47,
#     'ManifestationId': 80055,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 121,
#       'ManifestationId': 247028,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 48,
#     'ManifestationId': 80056,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 123,
#       'ManifestationId': 247030,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 49,
#     'ManifestationId': 80057,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 125,
#       'ManifestationId': 247032,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 50,
#     'ManifestationId': 80058,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 128,
#       'ManifestationId': 247035,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]}],
#   'OutstackConditionIds': []},
#  {'Id': 54864,
#   'KeyInId': 54864,
#   'PaperIndex': 4,
#   'Contests': [{'Id': 51,
#     'ManifestationId': 35979,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 129,
#       'ManifestationId': 111414,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 52,
#     'ManifestationId': 35980,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 132,
#       'ManifestationId': 111417,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 53,
#     'ManifestationId': 35981,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 133,
#       'ManifestationId': 111418,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 54,
#     'ManifestationId': 35982,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 135,
#       'ManifestationId': 111420,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 55,
#     'ManifestationId': 35983,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 137,
#       'ManifestationId': 111422,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 56,
#     'ManifestationId': 35984,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 140,
#       'ManifestationId': 111425,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 57,
#     'ManifestationId': 35985,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 141,
#       'ManifestationId': 111426,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 59,
#     'ManifestationId': 35987,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 145,
#       'ManifestationId': 111428,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 60,
#     'ManifestationId': 35988,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 148,
#       'ManifestationId': 111431,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 61,
#     'ManifestationId': 35989,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 149,
#       'ManifestationId': 111432,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]},
#    {'Id': 62,
#     'ManifestationId': 35990,
#     'Undervotes': 0,
#     'Overvotes': 0,
#     'OutstackConditionIds': [],
#     'Marks': [{'CandidateId': 152,
#       'ManifestationId': 111435,
#       'PartyId': 0,
#       'Rank': 1,
#       'MarkDensity': 0,
#       'IsAmbiguous': False,
#       'IsVote': True,
#       'OutstackConditionIds': []}]}],
#   'OutstackConditionIds': []}]

# %%
dfs = []
for file_path in tqdm.tqdm(glob.glob('./CVR_Export/CvrExport_*.json')):
    with open(file_path, 'r') as f:
        res = json.load(f)
    crv_export_df = pd.DataFrame(res['Sessions'])
    dfs.append(crv_export_df.apply(lambda x: raw_ballot_to_flat(x), axis=1, result_type='expand').set_index('key_in_id'))

raw_ballot_contest_results = pd.concat(dfs)
# Out:
#   0%|          | 0/22194 [00:00<?, ?it/s]

# %%
col_sort_key = lambda xs: [0 if not x.startswith('contest_') else int(x.split('_')[1]) for x in xs]

ballot_contest_results_annotated = raw_ballot_contest_results.copy()
ballot_contest_results_annotated['precint_desc'] = ballot_contest_results_annotated['precinct_portion_id'].apply(
    lambda x: cvr_precinct_portion_manifest_df.loc[x,'Description'])
ballot_contest_results_annotated['ballot_type_desc'] = ballot_contest_results_annotated['ballot_type_id'].apply(
    lambda x: ballot_type_contest_manifest_df.loc[x,'Description'])
ballot_contest_results_annotated['tabulator_desc'] = ballot_contest_results_annotated['tabulator_id'].apply(
    lambda x: cvr_tabulator_df.loc[x,'Description'])

# Sort columns and rename
ballot_contest_results_annotated.sort_index(axis=1, key=col_sort_key, inplace=True)
ballot_contest_results_annotated.columns = [
    contest_manifest_df.loc[int(x.split('_')[1]), 'Description'] if 
    x.startswith('contest_') else 
    x for x in ballot_contest_results_annotated.columns
]
ballot_contest_results_annotated
# Out:
#                tabulator_desc precint_desc       ballot_type_desc  \
# key_in_id
# 60445.0    ICC04 Vote by Mail     PCT 7849   Ballot Type 16 - VBM
# 62589.0    ICC04 Vote by Mail     PCT 9446   Ballot Type 24 - VBM
# 54326.0    ICC04 Vote by Mail     PCT 1132    Ballot Type 3 - VBM
# 54325.0    ICC04 Vote by Mail     PCT 1132    Ballot Type 3 - VBM
# 62229.0    ICC04 Vote by Mail     PCT 9426   Ballot Type 24 - VBM
# ...                       ...          ...                    ...
# 58688.0    ICC12 Vote by Mail     PCT 7528  Ballot Type 10 - POLL
# 58685.0    ICC12 Vote by Mail     PCT 7528  Ballot Type 10 - POLL
# 58687.0    ICC12 Vote by Mail     PCT 7528  Ballot Type 10 - POLL
# 58689.0    ICC12 Vote by Mail     PCT 7528  Ballot Type 10 - POLL
# 58686.0    ICC12 Vote by Mail     PCT 7528  Ballot Type 10 - POLL
#
#            tabulator_id  ballot_type_id  precinct_portion_id  GOVERNOR  \
# key_in_id
# 60445.0             8.0            57.0                274.0       2.0
# 62589.0             8.0            69.0                453.0       NaN
# 54326.0             8.0            27.0                 29.0       NaN
# 54325.0             8.0            27.0                 29.0       2.0
# 62229.0             8.0            69.0                435.0       NaN
# ...                 ...             ...                  ...       ...
# 58688.0            24.0            52.0                165.0       NaN
# 58685.0            24.0            52.0                165.0       2.0
# 58687.0            24.0            52.0                165.0       NaN
# 58689.0            24.0            52.0                165.0       NaN
# 58686.0            24.0            52.0                165.0       NaN
#
#            LIEUTENANT GOVERNOR  SECRETARY OF STATE  CONTROLLER  ...  \
# key_in_id                                                       ...
# 60445.0                    4.0                 6.0         8.0  ...
# 62589.0                    NaN                 NaN         NaN  ...
# 54326.0                    NaN                 NaN         NaN  ...
# 54325.0                    4.0                 6.0         7.0  ...
# 62229.0                    NaN                 NaN         NaN  ...
# ...                        ...                 ...         ...  ...
# 58688.0                    NaN                 NaN         NaN  ...
# 58685.0                    4.0                 6.0         7.0  ...
# 58687.0                    NaN                 NaN         NaN  ...
# 58689.0                    NaN                 NaN         NaN  ...
# 58686.0                    NaN                 NaN         NaN  ...
#
#            Measure E  Measure F  Measure G  Measure H  Measure I  Measure J  \
# key_in_id
# 60445.0          NaN        NaN        NaN        NaN        NaN        NaN
# 62589.0        132.0      134.0      136.0      138.0      139.0      142.0
# 54326.0          NaN        NaN        NaN        NaN        NaN        NaN
# 54325.0          NaN        NaN        NaN        NaN        NaN        NaN
# 62229.0        132.0      133.0      135.0      137.0      139.0      142.0
# ...              ...        ...        ...        ...        ...        ...
# 58688.0          NaN        NaN        NaN        NaN        NaN        NaN
# 58685.0          NaN        NaN        NaN        NaN        NaN        NaN
# 58687.0          NaN        NaN        NaN        NaN        NaN        NaN
# 58689.0        131.0      134.0      135.0      137.0      140.0      142.0
# 58686.0          NaN        NaN        NaN        NaN        NaN        NaN
#
#            Measure L  Measure M  Measure N  Measure O
# key_in_id
# 60445.0          NaN        NaN        NaN        NaN
# 62589.0        146.0      148.0      149.0      152.0
# 54326.0          NaN        NaN        NaN        NaN
# 54325.0          NaN        NaN        NaN        NaN
# 62229.0        145.0      148.0      150.0      152.0
# ...              ...        ...        ...        ...
# 58688.0          NaN        NaN        NaN        NaN
# 58685.0          NaN        NaN        NaN        NaN
# 58687.0          NaN        NaN        NaN        NaN
# 58689.0        145.0      148.0      150.0      151.0
# 58686.0          NaN        NaN        NaN        NaN
#
# [1526931 rows x 67 columns]

# %%
# Can compare governor results against summary here:
#    https://sfelections.sfgov.org/november-8-2022-election-results-detailed-reports
# Seems we're off by a bit
ballot_contest_results_annotated.groupby('GOVERNOR').count()
# Out:
#           tabulator_desc  precint_desc  ballot_type_desc  tabulator_id  \
# GOVERNOR
# 1.0                44221         44221             44221         44221
# 2.0               257286        257286            257286        257286
#
#           ballot_type_id  precinct_portion_id  LIEUTENANT GOVERNOR  \
# GOVERNOR
# 1.0                44221                44221                42508
# 2.0               257286               257286               247452
#
#           SECRETARY OF STATE  CONTROLLER  TREASURER  ...  Measure E  \
# GOVERNOR                                             ...
# 1.0                    42495       42764      42607  ...        454
# 2.0                   247882      245816     244960  ...       3389
#
#           Measure F  Measure G  Measure H  Measure I  Measure J  Measure L  \
# GOVERNOR
# 1.0             456        469        444        464        457        468
# 2.0            3468       3539       3347       3500       3403       3505
#
#           Measure M  Measure N  Measure O
# GOVERNOR
# 1.0             471        447        462
# 2.0            3517       3368       3423
#
# [2 rows x 66 columns]

# %% [markdown]
# ## Why our data might look wrong (it's close though)
#
# Comparing against reported data [here](https://www.sfelections.org/results/20221108/data/20221201/summary.pdf)
#
# Looking at just the case for the Governor.  Seeing opposite signs and similar magnitude makes me think we just need to look at the amended ballot info (right now we're just pulling down the original.  The total diff has us over-reporting, possible that there's some metadata in the outstack conditions that might invalidate a vote (and we could pull that in).
#
#
# |              | **Newsome** | **Dahle**  | **Total**  |
# |--------------|-------------|------------|------------|
# | **Actual**   | 257,402     | 44,064     | 301,466    |
# | **Our Data** | 257,286     | 44,221     | 301,507    |
# | **Diff**     | -116        | 157        | 41         |

# %%
44221-44064
# Out:
# 157
